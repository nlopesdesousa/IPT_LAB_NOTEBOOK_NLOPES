# %% [markdown]
# #### Day report 27/11/25
#
# 8h-12h : impact sound measurements were performed on the battery using the previous setup; to improve measurement precision, the setup was placed inside a soundproof box, with a wire mechanism ensuring the pendulum was released from a consistent height.
#
# <img src="wire_mechanism.jpeg" width="360"/><img src="set_up_grand_angle.jpeg" width="360"/><img src="setup_rapproche.jpeg" width="360"/>

# %%
from IPython.display import HTML

HTML("""
<div style="display: flex; justify-content: center; gap: 20px;">
    <div>
        <p style="text-align:center;"><b>Pendulum drop</b></p>
        <video width="300" controls>
            <source src="pendulum_drop.MOV" type="video/mp4">
        </video>
    </div>
</div>
""")
# Out:
# <div style="display: flex; justify-content: center; gap: 20px;">
#     <div>
#         <p style="text-align:center;"><b>Pendulum drop</b></p>
#         <video width="300" controls>
#             <source src="pendulum_drop.MOV" type="video/mp4">
#         </video>
#     </div>
# </div>

# %% [markdown]
# The recordings were made using a smartphone and saved with the Audacity application. In total, 28 discharged batteries of various brands and discharge levels (defined as a voltage below 1.35 V) and 19 charged batteries (with a voltage above 1.5 V) were measured. The summary table is as follows :
#
# <img src="differents_brands.jpeg" width="400"/><img src="tableau_piles_echantillons.png" width="700"/>
