# %% [markdown]
# | Battery number | Consumed capacity (mAh) | Discharge time |
# |-----------|-----------|-----------|
# | 1. (test battery) | 1363  | -  |
# | 2.  | 104  | 13min09s |
# | 3.  | 200  | 25min11s  |
# | 4.  | 301  | 37min55s  |
# | 5.  | 400  | 50min20s  |
# | 6.  | 500  | 62min54s  |
# | 7.  | 600  | 75min32s  |
# | 8.  | 700  | 88min04s  |
# | 9.  | 800  | 100min26s  |
# | 10. | 900  | 113min07s  |
# | 11. | 1002 | 126min15s  |
# | 12. | 1100 | 138min38s  |
# | 13. | 1300 | 163min37s  |

# %% [markdown]
# Table : different state of charge, discharged batteries using the discharger. The first battery is a test battery used to evaluate the maximum possible discharge with the device. However, it is still possible that a greater discharge could be achieved with our new procedure.

# %% [markdown]
# <img src="batteries_numbers.jpeg" width="500"/>
