# %% [markdown]
# #### Day report 03/10/25
#
# All day: Discharging batteries at different levels. \
# 8h-9h : Sharing personal research; ultrasound approaches proved difficult to implement, while vibrations could be exploited \
# 9h-9h30 : IPT meeting, found out about nationals new format, 4 questions to prepare \
# 10h : Received parts for the torsion pendulum to evaluate possible internal friction — results were inconclusive:
# 1. To hold the battery securely, the part must be tightened firmly, which tends to damage the outer casing (destructive), and if it is not tightened enough, the setup does not work
# 2. During oscillation tests, no measurable torsion was detected, and the external plastic casing was damaged.
#
# $\rightarrow$ Additionally, even if some effects were visible, there would likely be no difference between batteries since the outer casing mainly influences the results, whereas the goal is to detect internal effects, this experiment was put aside \
# 10h30 : Discussion with our professors; we decided to focus on potential variations in the cylinder’s angular momentum/moment of inertia and the use of the cylinder as a resonance chamber. \
# 11h : Attempted to compare two batteries (a new one and battery #10) by rolling them down an approximately 80 cm inclined plane with a slight angle. The results were inconclusive, as both batteries moved at the same speed. Deductions: either the plane is not long enough to observe a difference, the reaction is too uniform to have an impact, or the difference in moment of inertia is too small to detect anything. \
# Research was conducted to design an experiment using the battery as a resonance chamber, aiming to correlate sound damping with the battery’s charge level, thus directly involving internal structures. It is expected that a charged battery is softer and thus damps more, while a discharged battery is more elastic and damps less. \
# 12h : Acquired a glass beaker to produce sound and tested placing the battery inside to see if the sound’s quality, duration, or damping changed. No clear differences were observed. Lunch break \
# 13h : While waiting for equipment, explored various approaches to exploit internal friction and its impact on motion attenuation. The vibration approach appears to be the most promising for utilizing this property

# %%
from IPython.display import Video

Video("damping_test.mp4", width=640, height=480)
# Out:
# <video src="damping_test.mp4" controls  width="640"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Video : small test by placing one dead (left) and one new battery (right) on a paper sheet, giving a smal tangential impulsion by moving the sheet and evaluate de damping of the motion. On the video, we might observe a smal difference in the amplitude of the oscillation/excitation and the time of the damping. However the motion looks highly dependent of the shape of the bottom of the battery (long flat), which leads us to think the experiment is to arbitrary, but we conclude that the damping side can be promising

# %% [markdown]
# 14h : Acquired a tuning fork to use the batteries as resonance chambers at controlled frequencies. It was difficult to use the battery as a resonance chamber because there was no suitable way to attach the tuning fork directly without affecting sound transmission. One avenue to explore could be building a custom resonance chamber. Another experiment involved attaching a battery to one branch of the tuning fork and listening to its sound. Although the effect was minimal (at least to the ear), it was observed that the tuning fork’s sound lasted longer and was clearer with a discharged battery, supporting the idea that a discharged battery is more elastic. However, the vibration approach still seems more promising at this time. \
# 15-16h : Acquired a vibration table. Several experiments were conducted, such as placing batteries standing in different positions on the plate and measuring their vibration absorption by seeing which batteries fell fastest as frequency increased, as well as other tests to discover additional properties. Unfortunately, no conclusions could be drawn as the battery movements appeared too random, with no correlation observed between charge level and behavior.

# %%
from IPython.display import Video

Video("vibrating_table.mp4", width=640, height=480)
# Out:
# <video src="vibrating_table.mp4" controls  width="640"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Video : Example of conducted test with the vibrating table. Two batteries of different charged state are placed next to each other, the frequency is progressively increased (from 100Hz to 10kHz) while keeping the amplitude around 10V. The idea was to esthablish if one of the battery would damp the vibrations more that an other (we would expect the charged one) by looking the amplitude of the oscillations of the batteries and more easily the first one to fall. Serveral repetitions of the experiment were done and the results looked unfortunately too random, no particular damping was observed and the first one to fall was not consistently the discharged one, which lead us to think this particular experimental set up was not the right track.

# %% [markdown]
# 17h : Returned to the tuning fork approach, as it was the only one to yield somewhat usable results. The experiment was repeated to verify its validity, which appeared conclusive (again, the test was preliminary and based on listening). The main challenge is to differentiate the sounds (sound intensity, frequency, duration) produced by the modified tuning fork. Several mobile apps were tested but none provided sufficiently precise analysis. However, since the lab rooms are noisy, the environment is likely unsuitable. A potential solution is to find a quieter room. A microphone was also acquired, so the next step is to learn how to use it and conduct further experiments.

# %%
from IPython.display import Audio
Audio("charged.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Recording : sound generated by a diapason on which one charged/new battery was attached (on one of the branches), the room was noisy and the microphone is an Iphone one, but we can hear a quick attenuated sound

# %%
Audio("discharged.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Recording : sound generated by a diapason on which one discharged battery was attached (on one of the branches), the room was noisy and the microphone is an Iphone one, but we can hear a more longer sound, even though very attenuated and low
