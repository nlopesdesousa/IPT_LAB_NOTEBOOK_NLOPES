# %% [markdown]
# #### Day report 24/11/25
#
# Summary of the tests and conclusions of the day :
#
# During the day, gain curves were measured using both the old and the new piezoelectric sensors, for several levels of mechanical clamping.
#
# <img src="gain_curve.png" width="700"/>
# Image : Typical gain curve for one of the batteries and one clamping mechanisme (light or tight didn't change tthe general aspect)
#
# Analysing them by associating it to an damped forced oscillator andd computing the $Q$ factor (inverse of the damping coefficient) :
#
# $$
# m\ddot{x}(t) + c\dot{x} + kx(t) = F_0\sin(\omega t) ~~~~~ Q = \frac{1}{2\zeta}, ~~~~\zeta = \text{damping coefficient}
# $$
#
# Different trends of the $Q$ factor were observed, in particular indicating that the more discharged the battery is, the stronger its damping effect. These measurements were performed in a low-energy regime, since the spectrum analyzer is limited to output voltages of only a few hundred millivolts. Nevertheless, this result is significant, as it suggests that charged and discharged batteries may already be distinguishable in a low-energy domain.
#
# The next step is to confirm the reproducibility of these trends. If validated, this would already provide a partial answer to the initial research question. To physically interpret and justify these observations, the gain curves could be decomposed into a set of harmonic oscillators associated with the dominant resonance frequencies. By analyzing, for instance, which resonant frequencies exhibit systematic variations in their quality factor, one can formulate hypotheses about their physical origin within the system. Resonances showing no clear trend could be attributed to the battery casing or to the experimental setup itself, with the casing likely corresponding to the dominant structural resonance, as it constitutes the largest fraction of the vibrating mass. Additional resonances may be artifacts related to the setup, such as the metallic clamping mechanism. In contrast, resonances exhibiting clear trends can reasonably be associated with internal changes in the battery.
#
#
#
#
#
# Maintenant, ce qu'il reste à faire est de confirmer ces trends et nous auront alors répondu à une partie de la question. Ce qu'il est possible de faire pour donner une interprétation et justification physique à nos trouvailles est décomposer notre courbe de gain en plusieurs oscillateurs harmoniques pour les fréquences principales, et alors, en regardant par exemple pour quelles fréquences principales une tendance de facteur de qualité peut être observée, il est possible de faire des hypothèses quant à ce que les fréquences représentent physiquement dans notre système. Par exemple, on pourrait attribuer les résonances qui n'ont pas de trends à la coque ou au set up, ouù on imaginerait que la coque représente la fréquence principale du fait qu'elle représente la majeure de partie de la structure résonnée. on pourrait imaginer aussi quelques résonances artéfacts liées au set up lui même, par exemple le métal du clamping mechanism. Et quand aux résonances qui ont une trend, on peut lier ca aux changeemnt internes de la pile. On peut aussi imaginer mesurer pour avoir une vision plus globale la mean du gain. Si celle ci est plus haute, alor son a de manière générale une meilleure transmission. On peut aussi calculer la std du gain. ci celle ci est plus haute cela signifiée qu'il y a des pics plus fins et haut. On pourrait alors y voir un facteur de qualité généralisé. Pour expliquer ces changements à basse énergie, on pourrait simplement imaginer que le gel (sans les grains) est plus visqueux pour une pile déchargée que pour une pile chargée, alors on aurait des facteurs de qualités plus faibles pour une pile déchargée. Ceci serait ne observation cohérente avec nos observation quand nous avons ouvert les piles. Il ne reste maintenant plus qu'à se mettre dans le bon nibveau d'énergie. Pour cela et pour continuer d'utiliser l'analyseur de spectre, on pourrait imaginer de mettre un amplificateur à la sortie de l'analyseur. Ainsi on pourrait faire entrer dans le piézo une quantité d'énergie qui nous permet d'observer l'amortissement dû au grains de zinc. On placerait alors à la sortie pour se replacer dans la zone toléré par l'analyseur de spectre.
