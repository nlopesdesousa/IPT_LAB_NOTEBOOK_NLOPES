# %% [markdown]
# #### Day report 12/11/25
#
# First results of the data analysis for the rebound experiment (see [Rebound experiment analysis](rebond_mesure/analysedonnees.ipynb)). The followinf
#
# <img src="FirstBounceComparison.png" width="360"/><img src="RestitutionCoefficientComparison.png" width="360"/><img src="RestitutionCoefficientFit.png" width="360"/>
