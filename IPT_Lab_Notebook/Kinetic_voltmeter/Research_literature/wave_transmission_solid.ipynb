# %% [markdown]
# Following the idea that to distinguish a discharged battery from a charged one, one must exploit differences in their internal structure, the following experiment could be considered : hold a battery horizontally, with one end in contact with a pendulum and the other end struck with a certain force. Through the transmission of waves inside the material, the pendulum is set into motion with a certain amplitude. \
# This idea is inspired by the YouTube video below (https://youtu.be/6SyX2DErJSc?si=wxFE9YCIuyyCaDpY) by TeageTube, which demonstrates the propagation of waves in a metal bar.

# %%
from IPython.display import Video

Video("wave_transmission_solid_experiment.mp4", width=640, height=480)
# Out:
# <video src="wave_transmission_solid_experiment.mp4" controls  width="640"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>
