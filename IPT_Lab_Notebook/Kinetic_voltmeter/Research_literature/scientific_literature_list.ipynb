# %% [markdown]
# Scientific literature about the bouncing effect of a discharged alkaline battery :
#
# 1. Hall, Johnathon M., et al. « Experiments To Illustrate the Chemistry and Bouncing Ability of Fresh and Spent Zinc–Manganese Oxide Alkaline Batteries ». Journal of Chemical Education, vol. 93, no 4, avril 2016, p. 676‑80. DOI.org (Crossref), https://doi.org/10.1021/acs.jchemed.5b00796.
# 2. Bhadra, Shoham, et al. « The Relationship between Coefficient of Restitution and State of Charge of Zinc Alkaline Primary LR6 Batteries ». Journal of Materials Chemistry A, vol. 3, no 18, avril 2015, p. 9395‑400. pubs.rsc.org, https://doi.org/10.1039/C5TA01576F.
#
#
# Scientific literature about other technical methods of evaluating state

# %% [markdown]
# https://www.youtube.com/watch?v=NVUCf8mB1Wg
