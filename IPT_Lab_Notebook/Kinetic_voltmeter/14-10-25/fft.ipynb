# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

def analyse_frequence_audio(fichier_audio, label=None):
    # Lire le fichier audio
    taux_echantillonnage, donnees = wavfile.read(fichier_audio)

    # Si le fichier est stéréo, on ne garde qu'un seul canal
    if donnees.ndim > 1:
        donnees = donnees[:, 0]

    # Nombre total d'échantillons
    N = len(donnees)

    # Appliquer la FFT
    fft_result = np.fft.fft(donnees)
    freqs = np.fft.fftfreq(N, d=1/taux_echantillonnage)

    # Garder seulement les fréquences positives
    freqs_pos = freqs[:N // 2]
    fft_magnitude = np.abs(fft_result[:N // 2])

    # Trouver la fréquence minimale et maximale avec une magnitude significative
    seuil = max(fft_magnitude) * 0.01  # seuil de 1% de l'amplitude max
    indices_utiles = np.where(fft_magnitude > seuil)[0]

    if len(indices_utiles) == 0:
        print(f"{label or fichier_audio} : Aucune fréquence significative détectée.")
        return

    freq_min = freqs_pos[indices_utiles[0]]
    freq_max = freqs_pos[indices_utiles[-1]]

    print(f"{label or fichier_audio} : Plage de fréquence détectée : {freq_min:.2f} Hz à {freq_max:.2f} Hz")

    # Tracer la courbe sur le même graphe
    plt.plot(freqs_pos, fft_magnitude, label=label or fichier_audio)

# === Analyse des fichiers ===
plt.figure(figsize=(12, 6))

analyse_frequence_audio("frappe_d1.wav", label="frappe déchargée 1")
analyse_frequence_audio("frappe_d2.wav", label="frappe déchargée 2")
analyse_frequence_audio("frappe_d3.wav", label="frappe déchargée 3")
analyse_frequence_audio("frappe_d4.wav", label="frappe déchargée 4")
#analyse_frequence_audio("frappe_d5.wav", label="frappe déchargée 5")
#analyse_frequence_audio("frappe_d6.wav", label="frappe déchargée 6")

# Configuration du graphique
plt.title("Spectre de fréquences (FFT) - Comparaison de fichiers audio")
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.xlim(0, 10000)  # Limite haute de fréquence (modifiable selon ton besoin)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# frappe déchargée 1 : Plage de fréquence détectée : 411.72 Hz à 44091.93 Hz
# frappe déchargée 2 : Plage de fréquence détectée : 487.36 Hz à 19707.20 Hz
# frappe déchargée 3 : Plage de fréquence détectée : 439.04 Hz à 19615.24 Hz
# frappe déchargée 4 : Plage de fréquence détectée : 440.07 Hz à 19476.24 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

def analyse_frequence_audio(fichier_audio, label=None):
    # Lire le fichier audio
    taux_echantillonnage, donnees = wavfile.read(fichier_audio)

    # Si le fichier est stéréo, on ne garde qu'un seul canal
    if donnees.ndim > 1:
        donnees = donnees[:, 0]

    # Nombre total d'échantillons
    N = len(donnees)

    # Appliquer la FFT
    fft_result = np.fft.fft(donnees)
    freqs = np.fft.fftfreq(N, d=1/taux_echantillonnage)

    # Garder seulement les fréquences positives
    freqs_pos = freqs[:N // 2]
    fft_magnitude = np.abs(fft_result[:N // 2])

    # Trouver la fréquence minimale et maximale avec une magnitude significative
    seuil = max(fft_magnitude) * 0.01  # seuil de 1% de l'amplitude max
    indices_utiles = np.where(fft_magnitude > seuil)[0]

    if len(indices_utiles) == 0:
        print(f"{label or fichier_audio} : Aucune fréquence significative détectée.")
        return

    freq_min = freqs_pos[indices_utiles[0]]
    freq_max = freqs_pos[indices_utiles[-1]]

    print(f"{label or fichier_audio} : Plage de fréquence détectée : {freq_min:.2f} Hz à {freq_max:.2f} Hz")

    # Tracer la courbe sur le même graphe
    plt.plot(freqs_pos, fft_magnitude, label=label or fichier_audio)

# === Analyse des fichiers ===
plt.figure(figsize=(12, 6))

analyse_frequence_audio("frappe_n1.wav", label="frappe chargée 1")
analyse_frequence_audio("frappe_n2.wav", label="frappe chargée 2")
#analyse_frequence_audio("frappe_n3.wav", label="frappe chargée 3")
analyse_frequence_audio("frappe_n4.wav", label="frappe chargée 4")
analyse_frequence_audio("frappe_n5.wav", label="frappe chargée 5")
analyse_frequence_audio("frappe_n6.wav", label="frappe chargée 6")

# Configuration du graphique
plt.title("Spectre de fréquences (FFT) - Comparaison de fichiers audio")
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.xlim(0, 10000)  # Limite haute de fréquence (modifiable selon ton besoin)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# frappe chargée 1 : Plage de fréquence détectée : 437.53 Hz à 41821.83 Hz
# frappe chargée 2 : Plage de fréquence détectée : 436.79 Hz à 42363.61 Hz
# frappe chargée 4 : Plage de fréquence détectée : 443.60 Hz à 19556.85 Hz
# frappe chargée 5 : Plage de fréquence détectée : 450.80 Hz à 19897.00 Hz
# frappe chargée 6 : Plage de fréquence détectée : 409.42 Hz à 42467.74 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

def analyse_frequence_audio(fichier_audio, label=None):
    # Lire le fichier audio
    taux_echantillonnage, donnees = wavfile.read(fichier_audio)

    # Si le fichier est stéréo, on ne garde qu'un seul canal
    if donnees.ndim > 1:
        donnees = donnees[:, 0]

    # Nombre total d'échantillons
    N = len(donnees)

    # Appliquer la FFT
    fft_result = np.fft.fft(donnees)
    freqs = np.fft.fftfreq(N, d=1/taux_echantillonnage)

    # Garder seulement les fréquences positives
    freqs_pos = freqs[:N // 2]
    fft_magnitude = np.abs(fft_result[:N // 2])

    # Trouver la fréquence minimale et maximale avec une magnitude significative
    seuil = max(fft_magnitude) * 0.01  # seuil de 1% de l'amplitude max
    indices_utiles = np.where(fft_magnitude > seuil)[0]

    if len(indices_utiles) == 0:
        print(f"{label or fichier_audio} : Aucune fréquence significative détectée.")
        return

    freq_min = freqs_pos[indices_utiles[0]]
    freq_max = freqs_pos[indices_utiles[-1]]

    print(f"{label or fichier_audio} : Plage de fréquence détectée : {freq_min:.2f} Hz à {freq_max:.2f} Hz")

    # Tracer la courbe sur le même graphe
    plt.plot(freqs_pos, fft_magnitude, label=label or fichier_audio)

# === Analyse des fichiers ===
plt.figure(figsize=(12, 6))

#analyse_frequence_audio("frappe_6_1.wav", label="frappe pile 6 1")
analyse_frequence_audio("frappe_6_2.wav", label="frappe pile 6 2")
#analyse_frequence_audio("frappe_6_3.wav", label="frappe pile 6 3")
#analyse_frequence_audio("frappe_6_4.wav", label="frappe pile 6 4")
analyse_frequence_audio("frappe_6_5.wav", label="frappe pile 6 5")
analyse_frequence_audio("frappe_6_6.wav", label="frappe pile 6 6")

# Configuration du graphique
plt.title("Spectre de fréquences (FFT) - Comparaison de fichiers audio")
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.xlim(0, 10000)  # Limite haute de fréquence (modifiable selon ton besoin)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# frappe pile 6 2 : Plage de fréquence détectée : 439.06 Hz à 19374.40 Hz
# frappe pile 6 5 : Plage de fréquence détectée : 407.30 Hz à 44086.01 Hz
# frappe pile 6 6 : Plage de fréquence détectée : 390.17 Hz à 44030.91 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

def analyse_frequence_audio(fichier_audio, label=None):
    # Lire le fichier audio
    taux_echantillonnage, donnees = wavfile.read(fichier_audio)

    # Si le fichier est stéréo, on ne garde qu'un seul canal
    if donnees.ndim > 1:
        donnees = donnees[:, 0]

    # Nombre total d'échantillons
    N = len(donnees)

    # Appliquer la FFT
    fft_result = np.fft.fft(donnees)
    freqs = np.fft.fftfreq(N, d=1/taux_echantillonnage)

    # Garder seulement les fréquences positives
    freqs_pos = freqs[:N // 2]
    fft_magnitude = np.abs(fft_result[:N // 2])

    # Trouver la fréquence minimale et maximale avec une magnitude significative
    seuil = max(fft_magnitude) * 0.01  # seuil de 1% de l'amplitude max
    indices_utiles = np.where(fft_magnitude > seuil)[0]

    if len(indices_utiles) == 0:
        print(f"{label or fichier_audio} : Aucune fréquence significative détectée.")
        return

    freq_min = freqs_pos[indices_utiles[0]]
    freq_max = freqs_pos[indices_utiles[-1]]

    print(f"{label or fichier_audio} : Plage de fréquence détectée : {freq_min:.2f} Hz à {freq_max:.2f} Hz")

    # Tracer la courbe sur le même graphe
    plt.plot(freqs_pos, fft_magnitude, label=label or fichier_audio)

# === Analyse des fichiers ===
plt.figure(figsize=(12, 6))

#analyse_frequence_audio("frappe_13_1.wav", label="frappe pile 13 1")
#analyse_frequence_audio("frappe_13_2.wav", label="frappe pile 13 2")
#analyse_frequence_audio("frappe_13_3.wav", label="frappe pile 13 3")
#analyse_frequence_audio("frappe_13_4.wav", label="frappe pile 13 4")
#analyse_frequence_audio("frappe_13_5.wav", label="frappe pile 13 5")
analyse_frequence_audio("frappe_13_6.wav", label="frappe pile 13 6")

# Configuration du graphique
plt.title("Spectre de fréquences (FFT) - Comparaison de fichiers audio")
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.xlim(0, 10000)  # Limite haute de fréquence (modifiable selon ton besoin)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# frappe pile 13 6 : Plage de fréquence détectée : 440.54 Hz à 20002.49 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

def analyse_frequence_audio(fichier_audio, label=None):
    # Lire le fichier audio
    taux_echantillonnage, donnees = wavfile.read(fichier_audio)

    # Si le fichier est stéréo, on ne garde qu'un seul canal
    if donnees.ndim > 1:
        donnees = donnees[:, 0]

    # Nombre total d'échantillons
    N = len(donnees)

    # Appliquer la FFT
    fft_result = np.fft.fft(donnees)
    freqs = np.fft.fftfreq(N, d=1/taux_echantillonnage)

    # Garder seulement les fréquences positives
    freqs_pos = freqs[:N // 2]
    fft_magnitude = np.abs(fft_result[:N // 2])

    # Trouver la fréquence minimale et maximale avec une magnitude significative
    seuil = max(fft_magnitude) * 0.01  # seuil de 1% de l'amplitude max
    indices_utiles = np.where(fft_magnitude > seuil)[0]

    if len(indices_utiles) == 0:
        print(f"{label or fichier_audio} : Aucune fréquence significative détectée.")
        return

    freq_min = freqs_pos[indices_utiles[0]]
    freq_max = freqs_pos[indices_utiles[-1]]

    print(f"{label or fichier_audio} : Plage de fréquence détectée : {freq_min:.2f} Hz à {freq_max:.2f} Hz")

    # Tracer la courbe sur le même graphe
    plt.plot(freqs_pos, fft_magnitude, label=label or fichier_audio)

# === Analyse des fichiers ===
plt.figure(figsize=(12, 6))

#analyse_frequence_audio("choc_plat_n1.wav", label="choc plat neuve 1")
analyse_frequence_audio("choc_plat_n2.wav", label="choc plat neuve 2")
#analyse_frequence_audio("choc_plat_d1.wav", label="choc plat vieille 1")
analyse_frequence_audio("choc_plat_d2.wav", label="choc plat vieille 2")

# Configuration du graphique
plt.title("Spectre de fréquences (FFT) - Comparaison de fichiers audio")
plt.xlabel("Fréquence (Hz)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.xlim(0, 10000)  # Limite haute de fréquence (modifiable selon ton besoin)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# choc plat neuve 2 : Plage de fréquence détectée : 0.00 Hz à 23583.92 Hz
# choc plat vieille 2 : Plage de fréquence détectée : 0.00 Hz à 20595.77 Hz
